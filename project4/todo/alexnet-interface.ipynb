pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/3960c45e-6a69-4231-953c-e39d6a1c2fd5.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/66fb4e4e-f965-4c0b-a1a1-78ba7f02b397.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/4675ba35-f929-48af-9f13-432b6eb8e1ff.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/f2eeb256-3419-4a93-8c00-43631c109f35.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/48fcd487-ebad-426c-9b18-d602dc1c5d89.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/9f2a3acd-e7ce-4086-9b0d-2956a406867e.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/6c4dadf3-acab-4800-a75f-8df33f00a25c.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/94315561-047d-4d74-921c-da7aa931b7f8.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/c9deb43b-f0d9-42b9-aff8-44f7ed5821aa.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/cad4f87b-69e2-4c0e-9b2f-a7537f5e799b.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/a2fc7229-c589-4a87-b65d-2baa87df956b.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/c2562f91-fa07-4c2e-bca3-4f9fdaa64c1d.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/015acd92-9b18-454c-b72b-8d9ef2fb68c9.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/82197482-bdbb-495d-af37-c851a39cc24c.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/3b68a4d7-3110-455c-a18a-dba686c99e72.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/6f26a4cb-4524-47cb-bc38-dacc5b6c5946.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/1317af4b-9994-41dc-9939-a8af6c2ae615.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/e07dfdde-f228-4749-a88b-9e0472698736.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/9b5ac465-018d-4654-b85a-97a0c433a681.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/3faf6262-3ac6-4678-9a5e-f56e47fbae5b.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/643168f9-1000-43fc-bc76-e81934e5dc40.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/f8e8821b-04fc-4e82-91b8-7b4222a4f29e.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/d40c2b19-008d-45e4-a4f9-5ae52f2e77ec.pkl
# /kaggle/input/nycu-ml-pattern-recognition-hw-4/released/train/class_0/bed708ae-6d9b-4f7c-a13d-b23808d255a8.pkl

# %%
import pickle
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from torch.utils.data import DataLoader, TensorDataset, ConcatDataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# GPU device
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)

# %%
# get file name
testFileName = list()
trainFileNameClass0 = list()
trainFileNameClass1 = list()
os.chdir('/kaggle/input/nycu-ml-pattern-recognition-hw-4/released/test')
testFileName = os.listdir()
os.chdir('../train/class_0')
trainFileNameClass0 = os.listdir()
os.chdir('../class_1')
trainFileNameClass1 = os.listdir()
os.chdir('../../')
# test file name
testFileName[0], trainFileNameClass0[0], trainFileNameClass1[0]
# Out:
# ('7c08c8c0-0064-40c3-a7cd-dda2b4043347.pkl',
#  '32767294-e76e-485e-91a0-c2a123498e01.pkl',
#  '3cc6a03d-7585-48f4-82cc-89448620b059.pkl')

# %%
def readData(filepath, filenamelist):
    FileExtensionRemove = []
    with open(filepath+filenamelist[0], 'rb') as f:
        data = np.array([pickle.load(f)])
    FileExtensionRemove.append(filenamelist[0][:-4])
    for filename in filenamelist[1:]:
        with open(filepath+filename, 'rb') as f:
            data = np.concatenate((data, np.array([pickle.load(f)])), axis=0)
        FileExtensionRemove.append(filename[:-4])
    return data, FileExtensionRemove

def DataPreprocess(trainX0, trainX1=None):
    # combine train data
    if trainX1 is None:
        trainX = trainX0
    else:
        trainX = np.concatenate((trainX0, trainX1))
    # Transform to 0 ~ 1
    trainX = trainX.astype('float32')
    trainX /= 255
    # To pytorch
    trainX = torch.from_numpy(trainX)
    if trainX1 is None:
        trainY = None
    else:
        trainY = torch.concatenate((torch.zeros((trainX0.shape[0],1)), 
                                    torch.ones((trainX1.shape[0],1))))
    return trainX, trainY

# %%
# Feature extraction model using AlexNet
class FeatureExtractor(nn.Module):
    def __init__(self):
        super(FeatureExtractor, self).__init__()
        base_model = models.alexnet(weights='IMAGENET1K_V1')
        self.feature_extractor = nn.Sequential(
            *list(base_model.features), 
            # nn.Dropout(p=0.2),
            nn.AdaptiveAvgPool2d((6, 6)),
            nn.Flatten(),
            *list(base_model.classifier[:-1])
        )
    
    def forward(self, x):
        x = self.feature_extractor(x)
        return x

# %%
# Number of tiles per bag
FEATURE_DIM = 4096
# MIL model
class MILModel(nn.Module):
    def __init__(self):
        super(MILModel, self).__init__()
        self.feature_extractor = FeatureExtractor()
        self.classifier = nn.Linear(FEATURE_DIM, 1)
    
    def forward(self, x):
        batch_size = x.size(0)
        num_tiles = x.size(1)
        x = x.view(-1, 3, 128, 128)
        features = self.feature_extractor(x)
        features = features.view(batch_size, num_tiles, -1)
        aggregated_features, _ = torch.max(features, dim=1)
        logits = self.classifier(aggregated_features)
        output = torch.sigmoid(logits)
        
        return output
    
    def predict(self, x):
        with torch.no_grad():
            ypred_prob = self(x)
            ypred = ypred_prob.clone().detach()
            ypred[ypred < 0.5] = 0
            ypred[ypred >= 0.5] = 1
            return ypred_prob, ypred

# %%
# Set random seed for reproducibility
torch.manual_seed(0)

# Initialize the model
model = MILModel().to(device)
model.load_state_dict(torch.load("/kaggle/input/train/alexnet-weight.pth"))
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 167MB/s]
# <All keys matched successfully>

# %%
model.eval()

# load test data and predict

predictArray = np.array([])
DataSizeBatch = 25
FileExtensionRemove = []
for i in range(int(len(testFileName)/DataSizeBatch)):
    print("Predict Batch ", i)
    
    startIndex = i * DataSizeBatch
    testX, Name = readData('test/', testFileName[startIndex:startIndex + DataSizeBatch])
    FileExtensionRemove += Name
    testX, _ = DataPreprocess(testX)
    
    pred_prob, pred_label = model.predict(testX.to(device))
    predictArray = np.concatenate((predictArray, pred_label.cpu().detach().numpy().T[0]))

predictArray = predictArray.astype(np.int64)
# Out:
# Predict Batch  0
# Predict Batch  1
# Predict Batch  2
# Predict Batch  3
# Predict Batch  4
# Predict Batch  5
# Predict Batch  6
# Predict Batch  7

# %%
# to pandas
submission = pd.DataFrame()
submission["image_id"] = FileExtensionRemove
submission["y_pred"] = predictArray

# %%
submission
# Out:
#                                  image_id  y_pred
# 0    7c08c8c0-0064-40c3-a7cd-dda2b4043347       1
# 1    cb206033-5968-44f9-bfc8-dab33bb57bae       1
# 2    355823c5-bc8e-4352-8892-10bf14ce866a       1
# 3    7f6d455e-47a0-4529-954d-0cc432f63d50       1
# 4    7a2304f3-f864-4c16-b683-468d87808661       1
# ..                                    ...     ...
# 195  4e4aef19-6408-46d9-9573-f8948c640e9d       1
# 196  9ea39c64-6d6c-4ff6-ae08-71ebca779275       1
# 197  e072b562-f2ef-42f7-8c60-ecf744a9469e       1
# 198  80b8987c-70c4-4274-9b46-893e3877a8cd       1
# 199  0a3d2366-2c62-489a-a9ec-069dbdfc07f3       1
#
# [200 rows x 2 columns]

# %%
submission.to_csv('/kaggle/working/submission.csv', index = None)
